# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from warnings import filterwarnings
filterwarnings("ignore")

# %%
data=pd.read_csv(r'C:\\Users\\santhosh\\Downloads\\archive (3)\\KAG_conversion_data.csv')
data
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 2      708771              916          103920  30-34      M        20
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion
# ...

# %%
data.head()
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# 2          693       0   0.00                 1                    0
# 3         4259       1   1.25                 1                    0
# 4         4133       1   1.29                 1                    1

# %%
data.tail()
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion
# 1138      1129773     252  358.189997                13                    2
# 1139       637549     120  173.880003                 3                    0
# 1140       151531      28   40.289999                 2                    0
# 1141       790253     135  198.710001                 8                    2
# 1142       513161     114  165.609999                 5                    2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ad_id                1143 non-null   int64
#  1   xyz_campaign_id      1143 non-null   int64
#  2   fb_campaign_id       1143 non-null   int64
#  3   age                  1143 non-null   object
#  4   gender               1143 non-null   object
#  5   interest             1143 non-null   int64
#  6   Impressions          1143 non-null   int64
#  7   Clicks               1143 non-null   int64
#  8   Spent                1143 non-null   float64
#  9   Total_Conversion     1143 non-null   int64
#  10  Approved_Conversion  1143 non-null   int64
# dtypes: float64(1), int64(8), object(2)
# memory usage: 98.4+ KB

# %%
data.columns
# Out:
# Index(['ad_id', 'xyz_campaign_id', 'fb_campaign_id', 'age', 'gender',
#        'interest', 'Impressions', 'Clicks', 'Spent', 'Total_Conversion',
#        'Approved_Conversion'],
#       dtype='object')

# %%
data.describe(include='all').T
# Out:
#                       count unique    top freq           mean            std  \
# ad_id                1143.0    NaN    NaN  NaN  987261.130359  193992.814738
# xyz_campaign_id      1143.0    NaN    NaN  NaN    1067.382327     121.629393
# fb_campaign_id       1143.0    NaN    NaN  NaN  133783.989501   20500.308622
# age                    1143      4  30-34  426            NaN            NaN
# gender                 1143      2      M  592            NaN            NaN
# interest             1143.0    NaN    NaN  NaN      32.766404      26.952131
# Impressions          1143.0    NaN    NaN  NaN  186732.132983  312762.183208
# Clicks               1143.0    NaN    NaN  NaN      33.390201      56.892438
# Spent                1143.0    NaN    NaN  NaN      51.360656      86.908418
# Total_Conversion     1143.0    NaN    NaN  NaN       2.855643       4.483593
# Approved_Conversion  1143.0    NaN    NaN  NaN       0.944007       1.737708
#
# ...

# %%
data.isnull().sum()
# Out:
# ad_id                  0
# xyz_campaign_id        0
# fb_campaign_id         0
# age                    0
# gender                 0
# interest               0
# Impressions            0
# Clicks                 0
# Spent                  0
# Total_Conversion       0
# Approved_Conversion    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
plt.title('Age of interest')
plt.bar(data['age'], data['interest'], color='red')
plt.xlabel('age')
plt.ylabel('interest')
plt.xticks(rotation = 90)
plt.yticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.countplot(x=data['interest'])
plt.title('Count of Interest')
plt.xticks(rotation=90)
plt.show()

# %%
plt.title('histogram:Sugars', color='red')
sns.histplot(data=data, x='Clicks', bins=50, color='yellow')
# Out:
# <Axes: title={'center': 'histogram:Sugars'}, xlabel='Clicks', ylabel='Count'>

# %%
plt.title('histogram kde: Genderwise Interest ')
sns.histplot(data=data, x='interest', hue='gender', kde=True)
plt.xticks(rotation = 90)
plt.show()

# %%
sns.distplot(data['Approved_Conversion'], color='c')
plt.title('Approved conversion')
# Out:
# Text(0.5, 1.0, 'Approved conversion')

# %%
g = sns.FacetGrid(data, col="age")
g.map(sns.histplot, "Clicks", color='red')

# %%
plt.pie(x=data['Impressions'])
plt.legend({'Male', 'Female'})
plt.show()

# %%
plt.title('sctter and plot of Interest wise approved conversion')
plt.scatter(data['interest'], data['Approved_Conversion'], color='red')
plt.plot(data['interest'], (data['Approved_Conversion']), color = 'black')
plt.colorbar()
plt.show()

# %%
plt.title('Interest wise approved_conversion')
plt.scatter(data['interest'], data['Approved_Conversion'], alpha = 0.5, color='indigo')
plt.xlabel('Interest')
plt.ylabel('Approved_Conversion')
plt.colorbar()
plt.show()

# %%
plt.title('Approved_conversions by Total_conversion')
plt.scatter(data['Approved_Conversion'], data['Total_Conversion'], alpha = 0.5, color='Orange')
plt.xlabel('Approved_Conversion')
plt.ylabel('Total_Conversion')
plt.show()

# %%
plt.title('Amount spent on interest')
plt.scatter(data['Spent'], data['interest'], c=data['interest'], alpha = 0.5, cmap = 'nipy_spectral')
plt.xlabel('Spent')
plt.ylabel('interest')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.pairplot(data, hue='age')

# %%
sns.jointplot(x=data['fb_campaign_id'], y=data['Spent'], kind='hex', color='green')
plt.xticks(rotation=90)
plt.show()

# %%
sns.jointplot(x=data['xyz_campaign_id'], y=data['Spent'], kind='reg', color='orange')

# %%
plt.figure(figsize = (10,5))
sns.boxplot(data=data, x="age", y="Clicks")
plt.title('Age wise no. ofclicks')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.violinplot(y=data['Total_Conversion'], x=data['age'])
plt.title('Total_conversion with age')
plt.xticks(rotation=90)
plt.show()

# %%
sns.jointplot(x=data['ad_id'], y=data['Clicks'], kind='kde', fill=True, color='indigo')
